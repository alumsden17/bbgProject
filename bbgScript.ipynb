# %%
#necessary packages and dataframes
import pandas as pd

import numpy as np
import bloombergProject as bg
x =r"C:\Users\Alec Lumsden\Downloads\DBG Data Set Presentation Prep Doc.xlsx"
fx_df = pd.read_excel(x,sheet_name ='FX' )

# %% [markdown]
# Momentum Monitors: RSI, Bollinger, and MACD indicators can be accessed by applying the momentum
#     - you can change the date range by editing line 2
#         for example you can change date to be .....

# %%
dir(bg)
# Out:
# ['MACD',
#  'RSI',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'dataRange',
#  'lnd',
#  'max_colwidth_doc',
#  'np',
#  'pd',
#  'plt',
#  'sys',
#  'timeSeries']

# %%
fx_df=fx_df.rename(columns={'Date':'date'})
dates = bg.dataRange(fx_df,'2015-09-01','2016-09-01')

fx_df = fx_df[dates]
# =bg.timeSeries(fx_df)

bg.RSI(fx_df,15,'USDJPY')
#fx_df.momentum('USDJPY',3)
# Out:
#           date        rsi  upper  lower
# 0   2015-09-03  40.531226     70     30
# 1   2015-09-04  33.217529     70     30
# 2   2015-09-05  35.137930     70     30
# 3   2015-09-06  35.137930     70     30
# 4   2015-09-07  37.451280     70     30
# ..         ...        ...    ...    ...
# 345 2016-08-13  40.990918     70     30
# 346 2016-08-14  40.990918     70     30
# 347 2016-08-15  44.716122     70     30
# 348 2016-08-16  46.111912     70     30
# 349 2016-08-17  66.856592     70     30
#
# [350 rows x 4 columns]

# %%
ex = fx_df['date'] > '2015-09-01'
fx_df[ex]

# %% [markdown]
# d
